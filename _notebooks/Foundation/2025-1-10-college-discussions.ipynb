# %% [raw]
# ---
# layout: post
# title: College Connections
# description: My connection to the college students
# permalink: /college/discussions
# menu: nav/tools_setup.html
# toc: true
# comments: true
# ---

# %% [markdown]
# # Notes from Discussions
#
# ## Practical Skills and Hobbies
#
# - **Disassembling and Reassembling Devices**
#   - *Speaker's Insight*: Taking apart devices and putting them back together helps in understanding their mechanics and enhances problem-solving abilities.
#
# - **Website Creation**
#   - *Speaker's Insight*: Building websites combines creativity with technical skills, resulting in functional and appealing online platforms.
#
# - **Command Line Navigation and Coding**
#   - *Speaker's Insight*: Using command prompts and coding strengthens programming skills and deepens understanding of computer operations.
#
# ## Project Management and Workflow
#
# - **Project-Based Hobbies**
#   - *Speaker's Insight*: Engaging in projects that can be divided into smaller tasks allows for focused effort and systematic completion.
#
# - **Reflecting on Past Projects**
#   - *Speaker's Insight*: Reviewing previous work aids in appreciating progress and applying past lessons to current endeavors.
#
# - **Embracing STEM Opportunities**
#   - *Speaker's Insight*: STEM fields offer vast opportunities for creativity and innovation, encouraging exploration and learning.
#
# ## Communication and Feedback
#
# - **Explaining Code Functionality**
#   - *Speaker's Insight*: Clearly articulating how code works is as important as the final product, demonstrating comprehension of the development process.
#
# - **Receiving Constructive Criticism**
#   - *Speaker's Insight*: Feedback from teachers and mentors identifies areas for improvement, enhancing skills through effective communication.
#
# ## Planning and Team Collaboration
#
# - **Strategic Preparation for Events**
#   - *Speaker's Insight*: Attending events like Purdue's recruiter sessions requires a clear plan to present ideas confidently and coherently.
#
# - **Implementing Scrum Methodology**
#   - *Speaker's Insight*: Utilizing Scrum techniques helps track progress, and if challenges arise, revisiting earlier stages prevents starting over.
#
# - **Utilizing Flowcharts and Diagrams**
#   - *Speaker's Insight*: Creating flowcharts and diagrams effectively illustrates website functionality, facilitating better communication of ideas.
#
# ## Leadership and Team Roles
#
# - **Employing Version Control Systems**
#   - *Speaker's Insight*: Using tools like Git enables seamless collaboration, ensuring team members can share progress and work together efficiently.
#
# - **Defining Roles Within a Team**
#   - *Speaker's Insight*: Assigning specific roles, such as Scrum Master, keeps the group organized and focused, promoting effective teamwork.
#
# - **Developing Leadership Skills**
#   - *Speaker's Insight*: Leading projects allows for teaching others, collaborative learning, and strengthening leadership abilities.
#
# ## College Admission Advice
#
# - **Building a Strong Application**
#   - *Speaker's Insight*: Highlight achievements and interests related to your intended major to showcase dedication and suitability for the field.
#
# - **Considering Community College Courses**
#   - *Speaker's Insight*: Taking classes at a community college offers preparation for university-level work and serves as a practical backup plan.
#
# - **Focusing on Skills Over GPA**
#   - *Speaker's Insight*: Admissions officers prioritize applicants' skills and passions over GPA alone; highlight abilities and experiences.
#
# - **Participating in Relevant Competitions**
#   - *Speaker's Insight*: Engaging in activities like building websites or F1N glider competitions demonstrates commitment and helps build valuable connections.
#
# - **Pursuing Genuine Interests in Clubs**
#   - *Speaker's Insight*: While joining multiple clubs adds variety, focusing on genuine passions ensures meaningful involvement and personal satisfaction.
#
# - **Crafting a Concise Resume**
#   - *Speaker's Insight*: Developing a one-page resume that highlights key achievements presents a clear and focused overview of qualifications.
#
# - **Creating a Portfolio Website**
#   - *Speaker's Insight*: Building a personal website to showcase projects and progress provides a comprehensive display of skills and experiences.
#
#
# ![image](image.png)
#
#
#
# # Looking sharp Mr Mort!!
